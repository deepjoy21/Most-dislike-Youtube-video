# %% [markdown]
# # Topic - Most dislike Youtube video.
#
# Here In this task I have tried to analyse most dislike Youtube videos based on the number of dislikes earned (in millions) in the respective videos. The task is done with the help of directories present in Python.

# %% [markdown]
# # Technical stack : Numpy Array, Pandas, Matplotlib, seaborn

# %%
import opendatasets as od
import os
import pandas as pd
import numpy as  nm
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Step 1: Reading the data from Source

# %%
# Reading daata from the link
dataset= 'https://www.kaggle.com/datasets/devrimtuner/list-of-mostdisliked-youtube-videos'
od.download(dataset)
data_dir = '.\list-of-mostdisliked-youtube-videos'
os.listdir(data_dir)
# Out:
# Skipping, found downloaded files in ".\list-of-mostdisliked-youtube-videos" (use force=True to force download)
# ['.ipynb_checkpoints']

# %% [markdown]
# # Step 2: Study the selected data

# %%
df = pd.read_csv('List of most-disliked YouTube videos.csv')
df
# Out:
#     Rank                                         Video name  \
# 0      1                                   †"Revenge 😂"[25]
# 1      2                      †"Wakt wakt ki baat h 😎🔥"[26]
# 2      3                            †"تحديات تيك توك 😂"[27]
# 3      4  †"YouTube Rewind 2018: Everyone Controls Rewin...
# 4      5                             "Baby Shark Dance"[29]
# 5      6                                         "Baby"[30]
# 6      7                             †"Sadak 2 Trailer"[32]
# 7      8                         "Johny Johny Yes Papa"[36]
# 8      9                                    "Bath Song"[37]
# 9     10         †"YouTube Rewind 2019: For the Record"[38]
# 10    11                            "Wheels on the Bus"[39]
# 11    12   †"Learning Colors – Colorful Eggs on a Farm"[40]
# 12    13                               "Lakdi ki kathi"[41]
# 13    14           †"Humpty the train on a fruits ride"[42]
# 14    15                          "Baa Baa Black Sheep"[43]
# ...

# %%
df.shape
# Out:
# (50, 8)

# %%
df.head (10)
# Out:
#    Rank                                         Video name  \
# 0     1                                   †"Revenge 😂"[25]
# 1     2                      †"Wakt wakt ki baat h 😎🔥"[26]
# 2     3                            †"تحديات تيك توك 😂"[27]
# 3     4  †"YouTube Rewind 2018: Everyone Controls Rewin...
# 4     5                             "Baby Shark Dance"[29]
# 5     6                                         "Baby"[30]
# 6     7                             †"Sadak 2 Trailer"[32]
# 7     8                         "Johny Johny Yes Papa"[36]
# 8     9                                    "Bath Song"[37]
# 9    10         †"YouTube Rewind 2019: For the Record"[38]
#
#                   Uploader / artist  Estimated Dislikes (millions)  \
# 0                  Lucas and Marcus                          53.68
# 1                  Bobby chourasiya                          29.04
# 2                        Land Stars                          21.00
# ...

# %%
df.tail (10)
# Out:
#     Rank                                         Video name  \
# 40    41  "Bath Song + More Nursery Rhymes & Kids Songs"...
# 41    42                      "Yes Yes Playground Song"[75]
# 42    43  "Wheels on the Bus + More Nursery Rhymes & Kid...
# 43    44  "Beach Song + More Nursery Rhymes & Kids Songs...
# 44    45               "Nani Teri Morni Ko Mor Le Gaye"[78]
# 45    46  †"Sesame Street: Healthy Teeth, Healthy Me: Br...
# 46    47                                "UPA CAVALINHO"[79]
# 47    48                                "Gangnam Style"[80]
# 48    49                           "No No Bedtime Song"[81]
# 49    50  "The Little Mermaid – Official Teaser Trailer"...
#
#              Uploader / artist  Estimated Dislikes (millions)  \
# 40  Cocomelon – Nursery Rhymes                           3.39
# 41  Cocomelon – Nursery Rhymes                           3.37
# 42  Cocomelon – Nursery Rhymes                           3.36
# ...

# %%
#*********descriptive statistics of given dataset*******************
df.describe()
# Out:
#            Rank  Estimated Dislikes (millions)
# count  50.00000                      50.000000
# mean   25.50000                       7.902800
# std    14.57738                       8.547595
# min     1.00000                       2.840000
# 25%    13.25000                       3.707500
# 50%    25.50000                       4.750000
# 75%    37.75000                       8.325000
# max    50.00000                      53.680000

# %%
#*********descriptive statistics to detect missing values in rows*******************
df.describe(include='all')
# Out:
#             Rank        Video name           Uploader / artist  \
# count   50.00000                50                          50
# unique       NaN                50                          36
# top          NaN  †"Revenge 😂"[25]  Cocomelon – Nursery Rhymes
# freq         NaN                 1                          12
# mean    25.50000               NaN                         NaN
# std     14.57738               NaN                         NaN
# min      1.00000               NaN                         NaN
# 25%     13.25000               NaN                         NaN
# 50%     25.50000               NaN                         NaN
# 75%     37.75000               NaN                         NaN
# max     50.00000               NaN                         NaN
#
#         Estimated Dislikes (millions)  \
# count                       50.000000
# unique                            NaN
# top                               NaN
# freq                              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Rank                                            50 non-null     int64
#  1   Video name                                      50 non-null     object
#  2   Uploader / artist                               50 non-null     object
#  3   Estimated Dislikes (millions)                   50 non-null     float64
#  4   Dislike count (before being hidden) (millions)  42 non-null     object
#  5   Dislikes (%)[B]                                 50 non-null     object
#  6   Upload date                                     50 non-null     object
#  7   Type of video (Style)                           50 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB

# %%
#**********to find the missing value**********
print("Any missing values?",df.isnull().values.any())
# Out:
# Any missing values? True

# %%
df.count()
# Out:
# Rank                                              50
# Video name                                        50
# Uploader / artist                                 50
# Estimated Dislikes (millions)                     50
# Dislike count (before being hidden) (millions)    42
# Dislikes (%)[B]                                   50
# Upload date                                       50
# Type of video (Style)                             50
# dtype: int64

# %%
#*************values count of a particular group***************
df['Dislikes (%)[B]'].value_counts()
# Out:
# 39.66%      2
# 77.67%      1
# 86.30%      1
# 44.37%      1
# 45.13%      1
# 74.56%      1
# 43.86%      1
# 39.62%      1
# 41.27%      1
# 85.93%      1
# 37.33%      1
# 41.63%      1
# 42.35%      1
# 45.20%      1
# 84.54%      1
# 40.13%      1
# 40.74%      1
# 41.36%      1
# 41.04%      1
# 41.66%      1
# 32.76%      1
# 10.99%      1
# 42.38%      1
# 35.59%      1
# 43.89%      1
# 68.37%      1
# 63.56%      1
# 60.00%      1
# 86.60%      1
# 31.70% *    1
# 38.26%      1
# 94.86%      1
# 40.76% *    1
# 41.88%      1
# 73.30%      1
# 40.70%      1
# 39.78%      1
# 42.75%      1
# 43.02%      1
# 43.12%      1
# 41.32%      1
# 43.33%      1
# 25.65%      1
# 44.18%      1
# 93.73%      1
# 28.30%      1
# 69.14%      1
# 9.97%       1
# 70.76%      1
# Name: Dislikes (%)[B], dtype: int64

# %%
#***************to group all the videos of targeted type*********************
df.groupby('Type of video (Style)').get_group('Music video for children')
# Out:
#     Rank                                         Video name  \
# 4      5                             "Baby Shark Dance"[29]
# 7      8                         "Johny Johny Yes Papa"[36]
# 8      9                                    "Bath Song"[37]
# 10    11                            "Wheels on the Bus"[39]
# 12    13                               "Lakdi ki kathi"[41]
# 14    15                          "Baa Baa Black Sheep"[43]
# 16    17  "Old MacDonald Had a Farm – Kids nursery rhyme...
# 18    19                             "Chal Chal Gurram"[47]
# 24    25  "D Billions – Shake, shake your body! Clap, Cl...
# 25    26  †"Wheels on the Bus | Mother Goose Club Playho...
# 27    28  †"Old MacDonald | CoComelon Nursery Rhymes & K...
# 28    29  "Phonics Song 2 with Two Words in 3D – ABC Alp...
# 30    31                  "Twinkle Twinkle Little Star"[59]
# 31    32                      "Yes Yes Vegetables Song"[60]
# 32    33                                   "Baby Shark"[61]
# ...

# %%
#**************values count of a particular group*******************
df['Type of video (Style)'].value_counts()
# Out:
# Music video for children          25
# Music video                       10
# YouTube Shorts                     4
# Educational video for children     3
# YouTube Rewind                     2
# Movie trailer                      1
# Comedy                             1
# Children's television series       1
# Video game trailer                 1
# Vlog                               1
# Film trailer                       1
# Name: Type of video (Style), dtype: int64

# %%
df.mean()
# Out:
# C:\Users\DEEPJOY DAS\AppData\Local\Temp\ipykernel_39872\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Rank                             25.5000
# Estimated Dislikes (millions)     7.9028
# dtype: float64

# %%
#****************showing only target data**************
print(df['Estimated Dislikes (millions)'])
# Out:
# 0     53.68
# 1     29.04
# 2     21.00
# 3     20.23
# 4     17.86
# 5     14.24
# 6     13.74
# 7     12.94
# 8     11.29
# 9      9.62
# 10     9.63
# 11     8.81
# 12     8.62
# 13     7.44
# 14     6.70
# 15     6.43
# 16     6.33
# 17     5.88
# 18     5.85
# 19     5.81
# 20     5.80
# 21     5.62
# 22     5.58
# 23     5.55
# 24     4.97
# 25     4.53
# 26     4.33
# 27     4.27
# 28     4.22
# 29     4.30
# 30     4.22
# 31     4.20
# 32     4.43
# 33     4.01
# 34     3.94
# 35     3.93
# 36     3.85
# 37     3.66
# 38     3.65
# 39     3.46
# 40     3.39
# 41     3.37
# 42     3.36
# 43     3.21
# 44     3.19
# 45     3.17
# 46     3.03
# 47     2.99
# 48     2.93
# 49     2.84
# Name: Estimated Dislikes (millions), dtype: float64

# %%
df.groupby('Uploader / artist').get_group('Cocomelon – Nursery Rhymes')
# Out:
#     Rank                                         Video name  \
# 10    11                            "Wheels on the Bus"[39]
# 14    15                          "Baa Baa Black Sheep"[43]
# 27    28  †"Old MacDonald | CoComelon Nursery Rhymes & K...
# 30    31                  "Twinkle Twinkle Little Star"[59]
# 31    32                      "Yes Yes Vegetables Song"[60]
# 32    33                                   "Baby Shark"[61]
# 39    40  "Yes Yes Vegetables Song + More Nursery Rhymes...
# 40    41  "Bath Song + More Nursery Rhymes & Kids Songs"...
# 41    42                      "Yes Yes Playground Song"[75]
# 42    43  "Wheels on the Bus + More Nursery Rhymes & Kid...
# 43    44  "Beach Song + More Nursery Rhymes & Kids Songs...
# 48    49                           "No No Bedtime Song"[81]
#
#              Uploader / artist  Estimated Dislikes (millions)  \
# 10  Cocomelon – Nursery Rhymes                           9.63
# ...

# %%
#**************descriptive statistics of column***************
df.describe(include = "object")
# Out:
#               Video name           Uploader / artist  \
# count                 50                          50
# unique                50                          36
# top     †"Revenge 😂"[25]  Cocomelon – Nursery Rhymes
# freq                   1                          12
#
#        Dislike count (before being hidden) (millions) Dislikes (%)[B]  \
# count                                              42              50
# unique                                             42              49
# top                                            19,943          39.66%
# freq                                                1               2
#
#           Upload date     Type of video (Style)
# count              50                        50
# unique             50                        11
# top     July 26, 2022  Music video for children
# freq                1                        25

# %% [markdown]
# # Step 3 : To check for Null value

# %%
#***************check for missing or null values**************
df.isnull()
# Out:
#      Rank  Video name  Uploader / artist  Estimated Dislikes (millions)  \
# 0   False       False              False                          False
# 1   False       False              False                          False
# 2   False       False              False                          False
# 3   False       False              False                          False
# 4   False       False              False                          False
# 5   False       False              False                          False
# 6   False       False              False                          False
# 7   False       False              False                          False
# 8   False       False              False                          False
# 9   False       False              False                          False
# 10  False       False              False                          False
# 11  False       False              False                          False
# ...

# %%
#***********check for null value in each column*****************
df.isnull().sum()
# Out:
# Rank                                              0
# Video name                                        0
# Uploader / artist                                 0
# Estimated Dislikes (millions)                     0
# Dislike count (before being hidden) (millions)    8
# Dislikes (%)[B]                                   0
# Upload date                                       0
# Type of video (Style)                             0
# dtype: int64

# %% [markdown]
# # Step 4 : To plot the Null value in the Heatmap

# %%
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Step 5 : Input data Visualisation

# %%
df= df['Uploader / artist'].value_counts().plot(kind='bar')
plt.title ('Total number of videos uploaded by various Uploader/artist')
plt.xlabel('Names of Uploader/artist')
plt.ylabel('Total number of videos')
plt.figure()

# %%
df= df['Type of video (Style)'].value_counts().plot(kind='bar')
plt.title ('Types of videos uploaded by various Uploader/artist')
plt.xlabel('Type of videos')
plt.ylabel('Total number of videos')
plt.figure()

# %%
df= df['Dislikes (%)[B]'].value_counts().plot(kind='bar')
plt.title ('Total number of dislikes in videos uploaded')
plt.xlabel('Percentage of dislikes')
plt.ylabel('Total number of dislikes')
plt.figure()

# %% [markdown]
# # Step 6: Exploratory Data Analysis

# %%
ax = sb.countplot(x = 'Uploader / artist',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sb.countplot(x = 'Type of video (Style)',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Conclusion:
#
#
# Here we have studied about the different types of videos uploaded by various artist/uploader.The number of most dislike video is "†Revenge", types of videos which is most uploaded is "Music video for children" using bar-graph and other information such as mean, nullvalue, etc.
